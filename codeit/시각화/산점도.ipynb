# %%
# %matplotlib inline
import pandas as pd

df = pd.read_csv('data/exam.csv')
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
df.plot(kind='scatter', x='math score',y='reading score')

# %%
df.plot(kind='scatter',x='math score',y='writing score')

# %%
df.plot(kind='scatter',x='reading score', y ='writing score')

# %% [markdown]
# ### 국가 지표 분석하기

# %%
df = pd.read_csv('data/world_indexes.csv',index_col=0)
df
# Out:
#                           Human Development Index HDI-2014  \
# Id
# Norway                                            0.943877
# Australia                                         0.934958
# Switzerland                                       0.929613
# Denmark                                           0.923328
# Netherlands                                       0.921794
# ...                                                    ...
# Burundi                                           0.399928
# Chad                                              0.391906
# Eritrea                                           0.390899
# Central African Republic                          0.350131
# Niger                                             0.348254
#
#                           Gini coefficient 2005-2013  \
# Id
# Norway                                         26.83
# Australia                                      34.01
# Switzerland                                    32.35
# ...

# %%
life = 'Life expectancy at birth- years'
inter = 'Internet users percentage of population 2014'
forest = 'Forest area percentage of total land area 2012'
carbon = 'Carbon dioxide emissionsAverage annual growth'

# %%
df.plot(kind='scatter', x=life, y=inter)

# %%
df.plot(kind='scatter', x=forest, y=carbon)

# %%
df.plot(kind='scatter', x=inter, y=forest)

# %%
df.plot(kind='scatter', x=life, y=carbon)

# %%
df.plot(kind='scatter', x=life, y=forest)
